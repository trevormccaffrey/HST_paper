# %% [markdown]
# There's too much going on in Gordon's notebook to resolve any issues we're having with an individual plot.  Construct the L--blueshift plot in this single notebook.

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import richardsplot as rplot
import palettable
from astropy.cosmology import FlatLambdaCDM; cosmo = FlatLambdaCDM(Om0=0.3, H0=70)
from astropy.table import Table
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# /opt/anaconda3/lib/python3.8/_collections_abc.py:832: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   self[key] = other[key]

# %%
plt.rcParams['xtick.top']   = True
plt.rcParams['ytick.right'] = True

#use this color palette throughout
cs = palettable.colorbrewer.qualitative.Dark2_5.mpl_colors

# %%
def plot_contour(xdata, ydata, c="k", mark=".", nlevels=3, ax=None, linewidths=0.5, s=3, alpha=1, label=None):
    if ax is None:
        ax = plt.gca()
    xmin, xmax = xdata.min()-0.25*abs(xdata.mean()), xdata.max()+0.25*abs(xdata.mean())
    ymin, ymax = ydata.min()-0.25*abs(ydata.mean()), ydata.max()+0.25*abs(ydata.mean())
    X, Y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
    positions = np.vstack([X.ravel(), Y.ravel()])
    values = np.vstack([xdata, ydata])
    kernel = stats.gaussian_kde(values)
    Z = np.reshape(kernel(positions).T, X.shape)
    z = kernel(values)
    
    #transform Z to a 0-1 range
    Z = (Z - Z.min())/(Z.max() - Z.min())
    z = (z - z.min())/(z.max() - z.min())
    
    #ax.contour(X, Y, Z, levels=nlevels, linewidths=1.5, colors=c)
    levels = ax.contour(X, Y, Z, levels=nlevels, linewidths=linewidths, colors=[c]).levels
    
    # mask points above density threshold
    x = np.ma.masked_where(z > levels[0], xdata)
    y = np.ma.masked_where(z > levels[0], ydata)
    ax.scatter(x, y, color=c, marker=mark, s=3, alpha=alpha, zorder=2, label=label)

# %% [markdown]
# ---
#
# Load data.  First from HST; includes 130 S07 objects and additional 78 HSLA objects with ICA.  N=208

# %%
hst = pd.read_csv("/Users/Trevor1/Dropbox/HST/final_tables/HST_CIV_Sulentic2007_HSLA2018_1Jan2023.csv")
#comment out next line if want to include "bad" CIV measurements
hst = hst[hst["CIVgood_tvm"].values==1]
hst.head()
# Out:
#       Final_Name       Name_sul07       z z_src r_z_sul07  CIV_blue_tvm  \
# 0     PG1322+659      PG 1322+659  0.1674   Sul       M03    542.446498
# 1         Mrk205         MRK 0205  0.0711   Sul       M03    266.508764
# 3  LBQS1138+0204   LBQS 1138+0204  0.3821   Sul      SDSS   1024.717970
# 4    J15395+4735  [HB89] 1538+477  0.7723   Sul       M03    611.392209
# 5          3C110           3C 110  0.7744   Sul       SPM   -493.636575
#
#    CIV_EW_tvm  CIVgood_tvm  CIV_blue_sul07  CIV_EW_sul07  ...  MBH_source  \
# 0   58.743636            1           310.0     65.833333  ...         NaN
# 1   88.957267            1            73.0     52.077562  ...         NaN
# 3    9.097499            1           536.0     33.333333  ...         NaN
# 4   33.244469            1           402.0     64.876033  ...         NaN
# 5   59.969524            1          -983.0     80.198020  ...         NaN
#
#    logEddRatio EddRatio_Source           SDSS_NAME   PLATE      MJD FIBERID  \
# ...

# %%
hst.columns
# Out:
# Index(['Final_Name', 'Name_sul07', 'z', 'z_src', 'r_z_sul07', 'CIV_blue_tvm',
#        'CIV_EW_tvm', 'CIVgood_tvm', 'CIV_blue_sul07', 'CIV_EW_sul07',
#        'F1450_spec (erg/s/cm2/A)', 'S2N_1450A', 'Inst_final', 'log M_BH',
#        '+err(log M_BH)', '-err(log M_BH)', 'MBH_source', 'logEddRatio',
#        'EddRatio_Source', 'SDSS_NAME', 'PLATE', 'MJD', 'FIBERID', 'IAU_sul07',
#        '_RA', '_DE'],
#       dtype='object')

# %%
names_hst = hst["Final_Name"].values

z_hst    = hst["z"].values
DLcm_hst = cosmo.luminosity_distance(z_hst).value*3.086e24 #convert Mpc to cm 

#compute luminosities in erg/s/Hz
#first convert flambda to fnu
fnu1450_hst    = hst["F1450_spec (erg/s/cm2/A)"].values * 1450. / (2.998e18/1450)
logLnu1450_hst = np.log10(4.*np.pi) + np.log10(fnu1450_hst) + 2*np.log10(DLcm_hst)

# %% [markdown]
# Now load CIV parameters from ICA and from Sulentic where available.

# %%
c4blueICA_hst = hst["CIV_blue_tvm"].values
c4blueS07_hst = hst["CIV_blue_sul07"].values

#save mask for points that actually belong to the Sulentic sample
maskS07 = (~np.isnan(c4blueS07_hst))
#save mask for points that have RM BH mass measurements
maskMBH = (~np.isnan(hst["log M_BH"].values))

# %% [markdown]
# ---
#
# And plot -- plan is to plot everything "as is".  That is, if there's no ICA measurement for a dataset, I'm not plotting it so we know where we stand.

# %%
ALPHA_ORIG = 0.25

##
fig, ax = plt.subplots(1, 1, figsize=(9,9))

###Next block of code plots the HST sample
#plot ICA measurements
ax.plot(logLnu1450_hst[~maskMBH], c4blueICA_hst[~maskMBH], marker="^", markersize=7, color=cs[4], label="HST Archive, no $M_{BH}$", linestyle="")
ax.plot(logLnu1450_hst[maskMBH], c4blueICA_hst[maskMBH], marker="o", markersize=10, color=cs[3], label="HST Archive, yes $M_{BH}$", linestyle="")

#plot faded S07 measurements for objects that have it
ax.plot(logLnu1450_hst[(maskS07)&(~maskMBH)], c4blueS07_hst[(maskS07)&(~maskMBH)], marker="x", markersize=7, 
        color=cs[4], alpha=ALPHA_ORIG, linestyle="")
#plot line connecting the two measurements 
ax.plot([logLnu1450_hst[(maskS07)&(~maskMBH)], logLnu1450_hst[(maskS07)&(~maskMBH)]],
        [c4blueS07_hst[(maskS07)&(~maskMBH)], c4blueICA_hst[(maskS07)&(~maskMBH)]],
        color=cs[4], alpha=ALPHA_ORIG, ls="-", zorder=1)

ax.plot(logLnu1450_hst[(maskS07)&(maskMBH)], c4blueS07_hst[(maskS07)&(maskMBH)], marker="x", markersize=7, 
        color=cs[3], alpha=ALPHA_ORIG, linestyle="")
#plot line connecting the two measurements 
ax.plot([logLnu1450_hst[(maskS07)&(maskMBH)], logLnu1450_hst[(maskS07)&(maskMBH)]],
        [c4blueS07_hst[(maskS07)&(maskMBH)], c4blueICA_hst[(maskS07)&(maskMBH)]],
        color=cs[3], alpha=ALPHA_ORIG, ls="-", zorder=1)

#add text for objects in "unexpected" region of this plot (low L high blue)
maskObjLabel = (((logLnu1450_hst<29.2)&(c4blueICA_hst>1000)) | (c4blueICA_hst>3000))
for i in range(maskObjLabel.sum()):
    ax.text(logLnu1450_hst[maskObjLabel][i], c4blueICA_hst[maskObjLabel][i], names_hst[maskObjLabel][i][:7], 
            fontsize=15, alpha=0.9, zorder=1)

#plot settings
ax.set_ylabel('CIV Blueshift [km\,s$^{-1}$]', fontsize=35)
ax.set_xlabel(r'log\,$L_{1450\AA}$ [erg\,s$^{-1}$\,Hz$^{-1}$]', fontsize=35)
ax.tick_params(axis='both', which='major', labelsize=27.5)
ax.legend(frameon=True, labelspacing=0.1, bbox_to_anchor=(1.0,1), prop={"size":20})

ax.set_ylim(-499.99, 5999)
#plt.xlim(26.5,32.3)
plt.show()

# %% [markdown]
# <hr style="border:15px solid gray">
#
# Now include SDSS objects.  For now, these are ~145,000 DR14 objects with CIV from Rankine+20.
#
# To remain as consistent as possible with the HST objects, I pulled L1350 measurements from Wu & Shen's spectral properties of DR16.

# %%
sdss_tbl = Table.read("/Users/Trevor1/Dropbox/catalogs/Rankine20_CIV_HeII_wDelGI_wdr16luminosity.fits")
names = [name for name in sdss_tbl.colnames if len(sdss_tbl[name].shape) <= 1]
sdss = sdss_tbl[names].to_pandas()
#next line cuts objects without luminosity at logL1350 (15828/145946, maybe just not in spectra?)
sdss = sdss[(sdss["LOGL1350_dr16"]>0)&(sdss["good"]==True)]
sdss.head()
# Out:
# WARNING: UnitsWarning: '-' did not parse as fits unit: Invalid character at col 0 If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'nanomaggies' did not parse as fits unit: At col 0, Unit 'nanomaggies' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# ...

# %%
lognuLnu1350_sdss = sdss["LOGL1350_dr16"].values
logLnu1350_sdss   = lognuLnu1350_sdss - np.log10(2.9918e18/1350)

# %%
c4blueICA_sdss = sdss["CIV_blue"].values

# %% [markdown]
# ---
#
# Now add GNIRS-DQS.  Found 196/226 matches to Rankine+20.

# %%
gnirs = pd.read_csv("/Users/Trevor1/Dropbox/catalogs/gnirsdqs_wRankine_wdr16Lum.csv")
gnirs = gnirs[((gnirs["good"]==True)&(gnirs["LOGL1350_dr16"].values>0))]
gnirs
# Out:
#                         SDSS  FWHM-Hb  EW-Hb  EW-Fe2          RA        DEC  \
# 0    b' J010615.93+101043.0'     2936     73       2   16.566375  10.178611
# 1    b' J141617.38+264906.1'     4574     29       9  214.072417  26.818361
# 2    b' J011538.72+242446.0'     3925     51      34   18.911333  24.412778
# 3    b' J093533.88+235720.5'     6686     94       2  143.891167  23.955694
# 5    b' J114350.30+362911.3'     4090     48      13  175.959583  36.486472
# ..                       ...      ...    ...     ...         ...        ...
# 215  b' J093251.98+023727.0'     5521     48      31  143.216583   2.624167
# 218  b' J144706.81+212839.2'     6113     56      14  221.778375  21.477556
# 219  b' J160552.97+292141.4'     4192     64       2  241.470708  29.361500
# 221  b' J233344.66+290251.5'     4068     55      45  353.436083  29.047639
# 223  b' J083255.63+182300.7'     3851     21       2  128.231792  18.383528
#
# ...

# %%
c4blueICA_gnirs       = gnirs["CIV_blue"].values
lognuLnu1350_gnirs    = gnirs["LOGL1350_dr16"].values
logLnu1350_gnirs      = lognuLnu1350_gnirs - np.log10(2.998e18/1350)

# %%
ALPHA_ORIG = 0.25
fig, ax = plt.subplots(1, 1, figsize=(9,9))

### Next block of code plots the HST sample
#plot ICA measurements
ax.plot(logLnu1450_hst[~maskMBH], c4blueICA_hst[~maskMBH], marker="^", markersize=12, 
        markerfacecolor=cs[4], markeredgecolor="k", label="HST, no $M_{BH}$", linestyle="", zorder=3)
ax.plot(logLnu1450_hst[maskMBH], c4blueICA_hst[maskMBH], marker="o", markersize=15, 
        markerfacecolor=cs[3], markeredgecolor="k", label="HST, yes $M_{BH}$", linestyle="", zorder=3)

#plot faded S07 measurements for objects that have it
"""
ax.plot(logLnu1450_hst[(maskS07)&(~maskMBH)], c4blueS07_hst[(maskS07)&(~maskMBH)], marker="x", markersize=7, 
        color=cs[4], alpha=ALPHA_ORIG, linestyle="")
#plot line connecting the two measurements 
ax.plot([logLnu1450_hst[(maskS07)&(~maskMBH)], logLnu1450_hst[(maskS07)&(~maskMBH)]],
        [c4blueS07_hst[(maskS07)&(~maskMBH)], c4blueICA_hst[(maskS07)&(~maskMBH)]],
        color=cs[4], alpha=ALPHA_ORIG, ls="-", zorder=1)

ax.plot(logLnu1450_hst[(maskS07)&(maskMBH)], c4blueS07_hst[(maskS07)&(maskMBH)], marker="x", markersize=7, 
        color=cs[3], alpha=ALPHA_ORIG, linestyle="")
#plot line connecting the two measurements 
ax.plot([logLnu1450_hst[(maskS07)&(maskMBH)], logLnu1450_hst[(maskS07)&(maskMBH)]],
        [c4blueS07_hst[(maskS07)&(maskMBH)], c4blueICA_hst[(maskS07)&(maskMBH)]],
        color=cs[3], alpha=ALPHA_ORIG, ls="-", zorder=1)
"""

#add text for objects in "unexpected" region of this plot (low L high blue)
maskObjLabel = (((logLnu1450_hst<29.2)&(c4blueICA_hst>1000)) | (c4blueICA_hst>3000))
for i in range(maskObjLabel.sum()):
    ax.text(logLnu1450_hst[maskObjLabel][i], c4blueICA_hst[maskObjLabel][i], names_hst[maskObjLabel][i][:7], 
            fontsize=15, alpha=0.85, zorder=1)
    

### Next block of code plots SDSS and GNIRS-DQS objects
#N.B. this block takes a while, so should comment out when testing
plot_contour(logLnu1350_sdss, c4blueICA_sdss, c=cs[2], mark="o", nlevels=[0.05, 0.25, 0.50, 0.75, 0.95], ax=ax, 
             linewidths=1.5, s=3, alpha=0.4, label="SDSS")
#ax.plot(logLnu1350_sdss, c4blueICA_sdss, marker="o", markersize=3, color=cs[2], alpha=0.35, 
#        label="SDSS", linestyle="", zorder=1)

#now GNIRS
ax.plot(logLnu1350_gnirs, c4blueICA_gnirs, marker="v", markersize=11, markerfacecolor=cs[2], markeredgecolor="k", label="GNIRS-DQS", linestyle="", zorder=3)

#plot settings
ax.set_ylabel('CIV Blueshift [km\,s$^{-1}$]', fontsize=35)
ax.set_xlabel(r'log\,$L_{1450\AA}$ [erg\,s$^{-1}$\,Hz$^{-1}$]', fontsize=35)
ax.tick_params(axis='both', which='major', labelsize=27.5)
#ax.legend(frameon=True, labelspacing=0.1, bbox_to_anchor=(1.0,1), prop={"size":20})
ax.legend(frameon=True, labelspacing=0.1, loc="upper left", prop={"size":20})

ax.set_ylim(-499.99, 5999)
ax.set_xlim(26.75,32.34)

plt.tight_layout()
plt.savefig("plots/L_versus_blue_ICA.pdf")
plt.show()

# %%
print("SDSS:")
Lrange_sdss = np.linspace(min(logLnu1350_sdss), max(logLnu1350_sdss), 15)
for i in range(1, len(Lrange_sdss)):
    maskLrange_i = ((logLnu1350_sdss>=Lrange_sdss[i-1])&(logLnu1350_sdss<Lrange_sdss[i]))
    print("%.2f < L < %.2f: N=%5d, Median blueshift=%.1f" % (Lrange_sdss[i-1], Lrange_sdss[i], maskLrange_i.sum(), np.median(c4blueICA_sdss[maskLrange_i])))
# Out:
# SDSS:
# 27.63 < L < 27.97: N=    1, Median blueshift=2704.4
# 27.97 < L < 28.31: N=    1, Median blueshift=2246.5
# 28.31 < L < 28.65: N=    0, Median blueshift=nan
# 28.65 < L < 28.99: N=    4, Median blueshift=1270.2
# 28.99 < L < 29.33: N=   23, Median blueshift=639.5
# 29.33 < L < 29.67: N=  277, Median blueshift=484.0
# 29.67 < L < 30.01: N= 4667, Median blueshift=334.0
# 30.01 < L < 30.34: N=30285, Median blueshift=383.6
# 30.34 < L < 30.68: N=51224, Median blueshift=558.9
# 30.68 < L < 31.02: N=29105, Median blueshift=835.6
# 31.02 < L < 31.36: N= 8662, Median blueshift=1152.2
# 31.36 < L < 31.70: N= 1335, Median blueshift=1455.6
# 31.70 < L < 32.04: N=  127, Median blueshift=1673.3
# 32.04 < L < 32.38: N=   17, Median blueshift=1845.2
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# ...
